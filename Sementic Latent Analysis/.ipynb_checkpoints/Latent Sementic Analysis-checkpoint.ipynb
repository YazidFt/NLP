# %%
import numpy as np
import matplotlib as plt
import nltk
from nltk.stem import WordNetLemmatizer

from sklearn.decomposition import TruncatedSVD
# %matplotlib inline

# %%
#Preprocessing the data first
lemmatizer = WordNetLemmatizer()

titles = [line.rstrip() for line in open('all_book_titles.txt')] 
stopwords = set(w.rstrip() for w in open('stopwords.txt'))

lemmatizer = WordNetLemmatizer()

def my_tokenizer(s):
    s=s.lower()
    tokens = nltk.tokenize.word_tokenize(s)
    tokens = [t for t in tokens if len(t)>2]
    #word into base form
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    tokens = [t for t in tokens if not t in stopwords]
    tokens = [t for t in tokens if not any(c.isdigit() for c in t)]
    return tokens



def tokens_to_vector(tokens):
    x = np.zeros(len(word_index_map)) 
    for token in tokens:
        i = word_index_map[token]
        x[i]=1
    return x    
    
    
#figure the index of each words by going entire the vocabulary
word_index_map = {}
current_index = 0
all_tokens = []
all_titles = []
index_word_map = {}


#Preprocessing the data
for title in titles:
        #title = title.encode('ascii','ignore')
        all_titles.append(title)
        tokens = my_tokenizer(title)
        all_tokens.append(tokens)
        for token in tokens:
            if token not in word_index_map:
                word_index_map[token] = current_index
                current_index += 1
                index_word_map[current_index]=token

    
#print(all_tokens)

N = len(all_tokens)
D = len(word_index_map)
X = np.zeros((D, N))

i=0
for tokens in all_tokens:
    X[:,i] = tokens_to_vector(tokens)
    i+=1
    

svd = TruncatedSVD()
Z = svd.fit_transform(X)

plt.scatter(Z[:,0],Z[:,1])
plt.show()
# Out:
# ['philosophy', 'sex', 'love', 'reader']
# ['reading', 'judaism', 'christianity', 'islam']
# ['microprocessor', 'principle', 'application']
# ['bernhard', 'edouard', 'fernow', 'story', 'north', 'american', 'forestry']
# ['encyclopedia', 'buddhism']
# ['motorola', 'microprocessor', 'family', 'programming', 'interfacing', 'application']
# ['american', 'anthem', 'student', 'edition', 'modern', 'era']
# ['read', 'literature', 'professor', 'lively', 'entertaining', 'guide', 'reading', 'line']
# ['mar', 'woman', 'venus', 'secret', 'sex', 'improving', 'communication', 'lasting', 'intimacy', 'fulfillment', 'giving', 'receiving', 'love', 'secret', 'passion', 'understanding', 'martian']
# ['religious', 'tradition', 'world', 'journey', 'africa', 'mesoamerica', 'north', 'america', 'judaism', 'christianity', 'islam', 'hinduism', 'buddhism', 'china']
# ['world', 'wisdom', 'sacred', 'text', 'world', 'religion']
# ['illustrated', 'world', 'religion', 'guide', 'wisdom', 'tradition']
# ['soul', 'sex', 'cultivating', 'life', 'act', 'love']
# ['thriving', 'chaos', 'handbook', 'management', 'revolution']
# ['blood', 'relative']
# ['wheelock', 'latin']
# ['choice', 'uncertainty', 'chaos', 'luck', 'thrive', 'despite']
# ['expanding', 'discourse', 'feminism', 'art', 'history']
# ['introduction', 'relativity', 'pure', 'applied', 'physic']
# ['experiment', 'microprocessor', 'interfacing', 'programming', 'hardware']
# ['pathophysiology', 'concept', 'application', 'health', 'care', 'professional']
# ['power', 'system', 'operation']
# ['machine', 'learning']
# ['e-commerce', 'strategy', 'technology', 'application']
# ['real', 'complex', 'analysis']
# ['schaum', 'outline', 'microprocessor', 'fundamental']
# ['schaum', 'microprocessor', 'fundamental', 'roger', 'tokheim', 'paperback']
# ['probability', 'random', 'variable', 'stochastic', 'process']
# ['medical', 'microbiology', 'immunology', 'picture']
# ['security', 'analysis', 'sixth', 'edition', 'foreword', 'warren', 'buffett']
# ['goodman', 'gilman', 'pharmacological', 'basis', 'therapeutic', 'twelfth', 'edition', 'goodman', 'gilman', 'pharmacological', 'basis', 'therapeutic']
# ['oca/ocp', 'oracle', 'database', 'all-in-one', 'exam', 'guide', 'cd-rom', 'exam', 'oracle', 'press']
# ['clinical', 'ethic', 'practical', 'approach', 'ethical', 'decision', 'clinical', 'medicine', 'seventh', 'edition', 'lange', 'clinical', 'science']
# ['understand', 'linguistics', 'teach', 'yourself', 'guide']
# ['harrison', 'principle', 'internal', 'medicine']
# ['basic', 'clinical', 'pharmacology', 'lange', 'basic', 'science']
# ['harrison', 'principle', 'internal', 'medicine', 'self-assessment', 'board', 'review', 'edition']
# ['strategic', 'database', 'marketing', 'masterplan', 'starting', 'managing', 'profitable', 'customer-based', 'marketing', 'program']
# ['review', 'medical', 'microbiology', 'immunology', 'twelfth', 'edition', 'lange', 'medical', 'book']
# ['tintinalli', 'emergency', 'medicine', 'manual', 'emergency', 'medicine', 'tintinalli']
# ['pharmacotherapy', 'pathophysiologic', 'approach']
# ['review', 'medical', 'microbiology', 'immunology']
# ['computer', 'organization']
# ['risk', 'management', 'insurance']
# ['design', 'analog', 'cmos', 'integrated', 'circuit']
# ['plant', 'design', 'economics', 'chemical', 'engineer']
# ['fluid', 'mechanic', 'engineering', 'application']
# ['operating', 'system', 'spiral', 'approach']
# ['essential', 'anatomy', 'physiology']
# ['database', 'management', 'system']
# ['introduction', 'probability', 'statistic', 'principle', 'application', 'engineering', 'computing', 'science']
# ['health', 'program', 'planning', 'educational', 'ecological', 'approach']
# ['geographic', 'information', 'system', 'application', 'forestry', 'natural', 'resource', 'management']
# ['fluid', 'mechanic', 'chemical', 'engineer']
# ['adaptation', 'studying', 'film', 'literature']
# ['american', 'art', 'history', 'culture']
# ['evolution', 'earth']
# ['introduction', 'woman', 'study', 'gender', 'transnational', 'world']
# ['fundamental', 'aerodynamics']
# ['introduction', 'forensics', 'criminalistics']
# ['introduction', 'biological', 'evolution']
# ['anatomy', 'physiology', 'integrative', 'approach']
# ['introduction', 'chemical', 'engineering', 'thermodynamics', 'chemical', 'engineering', 'thermodynamics']
# ['human', 'geography']
# ['theater', 'experience']
# ['bioinformatics', 'computing', 'perspective']
# ['experience', 'sociology']
# ['electronic', 'principle']
# ['earth', 'introduction', 'earth', 'science']
# ['essential', 'world', 'regional', 'geography']
# ['physical', 'geology']
# ['stern', 'introductory', 'plant', 'biology']
# ['business', 'statistic', 'communicating']
# ['digital', 'electronics', 'principle', 'application']
# ['medical', 'insurance', 'pharmacy', 'technician']
# ['insurance', 'medical', 'office', 'patient', 'payment']
# ['law', 'ethic', 'health', 'profession']
# ['foundation', 'microbiology']
# ['microbiology', 'human', 'perspective']
# ['introduction', 'programming', 'java', 'solving', 'approach']
# ['modern', 'computer', 'network', 'source', 'approach']
# ['business', 'driven', 'information', 'system']
# ['real', 'estate', 'finance', 'investment', 'real', 'estate', 'finance', 'investment']
# ['human', 'anatomy']
# ['hole', 'essential', 'human', 'anatomy', 'physiology']
# ['seeley', 'principle', 'anatomy', 'physiology']
# ['anatomy', 'physiology', 'unity', 'form', 'function']
# ['seeley', 'essential', 'anatomy', 'physiology']
# ['hole', 'human', 'anatomy', 'physiology']
# ['human', 'anatomy']
# ['vander', 'human', 'physiology']
# ['power', 'choice', 'introduction', 'political', 'science']
# ['history', 'western', 'art']
# ['reconstructing', 'gender']
# ['mechanic', 'material']
# ['fluid', 'mechanic', 'fundamental', 'application']
# ['microelectronic', 'circuit', 'design']
# ['fundamental', 'electric', 'circuit']
# ['cmos', 'digital', 'integrated', 'circuit', 'analysis', 'design']
# ['microelectronics', 'circuit', 'analysis', 'design']
# ['computer', 'organization']
# ['power', 'electronics']
# ['theater', 'experience']
# ['finance', 'application', 'theory']
# ['essential', 'investment', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['essential', 'corporate', 'finance', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['understanding', 'human', 'sexuality']
# ['biology']
# ['ecology', 'concept', 'application']
# ['environmental', 'science']
# ['narrative', 'history', 'volume']
# ['differential', 'equation', 'engineer', 'scientist']
# ['elementary', 'statistic']
# ['film', 'history', 'introduction']
# ['film', 'art', 'introduction']
# ['art', 'watching', 'film']
# ['studying', 'religion']
# ['fundamental', 'aerodynamics']
# ['vector', 'mechanic', 'engineer', 'static', 'dynamic']
# ['thermodynamics', 'engineering', 'approach']
# ['simulation', 'modeling', 'analysis']
# ['statistical', 'technique', 'business', 'economics']
# ['essential', 'business', 'statistic']
# ['microbiology', 'fundamental', 'clinical', 'approach']
# ['prescott', 'microbiology']
# ['microbiology', 'system', 'approach']
# ['contemporary', 'nutrition']
# ['chemistry', 'molecular', 'nature', 'matter', 'change']
# ['introduction', 'chemistry', 'third', 'edition']
# ['chemistry']
# ['principle', 'chemistry']
# ['chemistry']
# ['organic', 'chemistry']
# ['chemistry', 'essential', 'concept']
# ['organic', 'biochemistry']
# ['organic', 'chemistry']
# ['organic', 'biological', 'chemistry']
# ['business', 'communication', 'developing', 'leader', 'networked', 'world']
# ['lesikar', 'business', 'communication', 'connecting', 'digital', 'world']
# ['business', 'administrative', 'communication']
# ['business', 'communication', 'building', 'critical', 'skill']
# ['concept', 'biology']
# ['biology', 'concept', 'investigation']
# ['human', 'physiology']
# ['seeley', 'anatomy', 'physiology']
# ['mader', 'understanding', 'human', 'anatomy', 'physiology']
# ['hole', 'essential', 'human', 'anatomy', 'physiology']
# ['advertising', 'promotion', 'integrated', 'marketing', 'communication', 'perspective']
# ['sex', 'gender']
# ['unfinished', 'nation', 'concise', 'history', 'american', 'people']
# ['experiencing', 'world', 'religion']
# ['chemistry', 'atom']
# ['chemistry', 'atom']
# ['essential', 'economics']
# ['economics']
# ['essential', 'economics', 'edition', 'mcgraw-hill', 'series', 'economics']
# ['urban', 'economics']
# ['environmental', 'economics', 'introduction', 'mcgraw-hill']
# ['broadcasting', 'cable', 'internet', 'beyond', 'introduction', 'modern', 'electronic', 'medium']
# ['pathway', 'astronomy']
# ['college', 'physic', 'integrated', 'approach', 'force', 'kinematics', 'fourth', 'edition']
# ['astronomy', 'journey', 'cosmic', 'frontier']
# ['physic', 'everyday', 'phenomenon']
# ['exploration', 'introduction', 'astronomy']
# ['pathway', 'astronomy']
# ['medical', 'insurance', 'integrated', 'claim', 'process', 'approach']
# ['university', 'physic', 'modern', 'physic']
# ['physical', 'science']
# ['physic', 'everyday', 'phenomenon']
# ['theater', 'lively', 'art']
# ['anthology', 'living', 'theater']
# ['survey', 'operating', 'system']
# ['survey', 'operating', 'system']
# ['basic', 'statistic', 'business', 'economics']
# ['applied', 'statistic', 'business', 'economics']
# ['business', 'statistic', 'practice', 'mcgraw-hill/irwin', 'series', 'operation', 'decision', 'science']
# ['business', 'research', 'method']
# ['microbiology', 'system', 'approach']
# ['foundation', 'microbiology']
# ['wardlaw', 'perspective', 'nutrition']
# ['contemporary', 'world', 'regional', 'geography']
# ['introduction', 'geography']
# ['introduction', 'geography']
# ['chemistry', 'context']
# ['international', 'economics']
# ['economics', 'basic', 'mcgraw-hill/irwin', 'series', 'economics']
# ['labor', 'economics']
# ['managerial', 'economics', 'business', 'strategy']
# ['computer', 'network', 'top', 'approach']
# ['introduction', 'object-oriented', 'programming', 'java']
# ['database', 'system', 'concept']
# ['java', 'programming', 'ground']
# ['algorithm']
# ['earth', 'introduction', 'earth', 'science']
# ['environmental', 'geology']
# ['exploring', 'geology']
# ['laboratory', 'manual', 'physical', 'geology']
# ['marine', 'biology']
# ['vertebrate', 'comparative', 'anatomy', 'function', 'evolution']
# ['understanding', 'business', 'edition']
# ['employment', 'law', 'business']
# ['business', 'law']
# ['matching', 'supply', 'demand', 'introduction', 'operation', 'management']
# ['molecular', 'biology']
# ['human', 'biology']
# ['biology']
# ['essential', 'biology']
# ['concept', 'biology']
# ['biology', 'concept', 'investigation']
# ['human', 'anatomy']
# ['electronic', 'medium', 'introduction']
# ['medium', 'ethic', 'issue']
# ['power', 'choice', 'introduction', 'political', 'science']
# ['music', 'appreciation']
# ['world', 'music', 'tradition', 'transformation']
# ['sociology', 'brief', 'introduction', 'edition']
# ['foundation', 'material', 'science', 'engineering']
# ['shigley', 'mechanical', 'engineering', 'design', 'mcgraw-hill', 'series', 'mechanical', 'engineering']
# ['thermodynamics', 'engineering', 'approach', 'edition']
# ['engineering', 'circuit', 'analysis']
# ['semiconductor', 'physic', 'device']
# ['international', 'marketing']
# ['consumer', 'behavior', 'building', 'marketing', 'strategy', 'edition']
# ['personal', 'finance', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['corporate', 'finance', 'core', 'principle', 'application', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['personal', 'finance']
# ['sexuality']
# ['transformation', 'woman', 'gender', 'psychology']
# ['human', 'sexuality', 'self', 'society', 'culture']
# ['biology']
# ['biology', 'laboratory', 'manual']
# ['calculus', 'transcendental', 'function']
# ['applied', 'calculus', 'business', 'economics', 'social', 'life', 'science', 'expanded', 'edition']
# ['calculus', 'business', 'economics', 'social', 'life', 'science', 'brief', 'version']
# ['ecology', 'global', 'insight', 'investigation']
# ['ecology', 'concept', 'application']
# ['principle', 'environmental', 'science', 'inquiry', 'application']
# ['film', 'art', 'introduction']
# ['scripture', 'world', 'religion']
# ['ethical', 'issue', 'modern', 'medicine', 'contemporary', 'reading', 'bioethics']
# ['philosophy']
# ['introduction', 'thermodynamics', 'heat', 'transfer', 'ee', 'software']
# ['earth', 'introduction', 'earth', 'science']
# ['unfinished', 'nation', 'concise', 'history', 'american', 'people', 'volume']
# ['foundation', 'microbiology', 'basic', 'principle']
# ['exploration', 'introduction', 'astronomy']
# ['organic', 'chemistry']
# ['thermodynamics', 'engineering', 'approach', 'student', 'resource', 'dvd']
# ['american', 'history', 'survey', 'volume']
# ['american', 'history', 'survey', 'volume']
# ['vector', 'mechanic', 'engineer', 'static']
# ['vector', 'mechanic', 'engineer', 'dynamic']
# ['unfinished', 'nation', 'concise', 'history', 'american', 'people', 'volume']
# ['fundamental', 'thermal-fluid', 'science', 'student', 'resource', 'dvd']
# ['fluid', 'mechanic', 'student', 'dvd']
# ['music', 'appreciation', 'brief', 'edition']
# ['loose-leaf', 'fundamental', 'financial', 'accounting']
# ['foundation', 'financial', 'management', 'time', 'value', 'money', 'card', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['elementary', 'statistic', 'step', 'step', 'approach', 'formula', 'card', 'data']
# ['package', 'principle', 'organic', 'biochemistry', 'connect', 'plus', 'access', 'card']
# ['microbiology', 'system', 'approach', 'connect', 'plus', 'access', 'card']
# ['ecology', 'global', 'insight', 'investigation', 'connect', 'plus', 'access', 'card']
# ['loose-leaf', 'edition', 'understanding', 'business']
# ['fundamental', 'corporate', 'finance', 'alternate', 'edition', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['biology']
# ['loose', 'leaf', 'version', 'anatomy', 'physiology', 'integrative', 'approach']
# ['loose', 'leaf', 'version', 'human', 'anatomy', 'physiology']
# ['loose', 'leaf', 'biology']
# ['anatomy', 'physiology', 'unity', 'form', 'function', 'connect', 'plus/learnsmart', 'semester', 'access', 'card', 'includes', 'apr', 'phils', 'online', 'access']
# ['loose-leaf', 'principle', 'corporate', 'finance']
# ['experience', 'music', 'audio', 'cd']
# ['loose', 'leaf', 'version', 'exploring', 'geology']
# ['loose', 'leaf', 'organic', 'biochemistry']
# ['loose', 'leaf', 'version', 'human', 'physiology']
# ['elementary', 'statistic', 'brief', 'data', 'formula', 'card']
# ['electronics', 'principle', 'application', 'student', 'data', 'cd-rom']
# ['biology', 'connect', 'plus', 'access', 'card']
# ['exploring', 'geology', 'connect', 'plus', 'access', 'card']
# ['music', 'appreciation', 'brief', 'connect', 'upgrade', 'edition']
# ['international', 'business', 'challenge', 'global', 'competition', 'edition']
# ['intermediate', 'accounting', 'annual', 'report']
# ['microbiology', 'fundamental', 'clinical', 'approach', 'connect', 'plus', 'learnsmart', 'semester', 'access', 'card']
# ['loose-leaf', 'organic', 'chemistry']
# ['benson', 'microbiological', 'application', 'complete', 'version', 'brown', 'microbioligical', 'application']
# ['film', 'art', 'introduction', 'connect', 'access', 'card']
# ['practical', 'business', 'math', 'procedure', 'handbook', 'student', 'dvd', 'wsj', 'insert']
# ['loose', 'leaf', 'fundamental', 'cost', 'accounting', 'connect', 'plus']
# ['foundation', 'microbiology', 'basic', 'principle']
# ['seeley', 'anatomy', 'physiology', 'connect', 'plus', 'access', 'card']
# ['loose', 'leaf', 'version', 'environmental', 'geology']
# ['loose', 'leaf', 'version', 'environmental', 'geology']
# ['exploring', 'social', 'psychology']
# ['music', 'appreciation', 'brief', 'edition']
# ['marketing']
# ['essential', 'marketing', 'marketing', 'strategy', 'planning', 'approach']
# ['marketing', 'management']
# ['preface', 'marketing', 'management']
# ['marketing']
# ['personal', 'finance', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'est']
# ['finance', 'application', 'theory']
# ['study', 'finance', 'managing', 'corporate', 'value', 'creation', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['health', 'psychology']
# ['international', 'accounting']
# ['ethical', 'obligation', 'decision', 'accounting', 'text']
# ['advanced', 'accounting']
# ['fundamental', 'advanced', 'accounting']
# ['combo', 'wardlaw', 'perspective', 'nutrition', 'connect', 'plus', 'semester', 'access', 'card']
# ['anatomy', 'physiology', 'integrative', 'approach', 'connect', 'plus/learnsmart', 'semester', 'access', 'card/apr', 'online', 'access/phils', 'online', 'access']
# ['statistical', 'technique', 'business', 'economics']
# ['essential', 'business', 'statistic']
# ['essential', 'business', 'statistic']
# ['nutritional', 'assessment']
# ['human', 'geography', 'landscape', 'human', 'activity']
# ['international', 'economics', 'mcgraw-hill', 'series', 'economics']
# ['public', 'finance']
# ['economics', 'edition', 'mcgraw-hill', 'series', 'economics']
# ['managerial', 'economics', 'foundation', 'business', 'analysis', 'strategy', 'mcgraw-hill', 'economics', 'series']
# ['essential', 'economics']
# ['economics', 'principle', 'policy', 'mcgraw-hill', 'series', 'economics']
# ['contemporary', 'labor', 'economics', 'mcgraw-hill', 'series', 'economics']
# ['exercise', 'physiology', 'theory', 'application', 'fitness', 'performance']
# ['concept', 'physical', 'fitness', 'active', 'lifestyle', 'wellness']
# ['introduction', 'physical', 'education', 'exercise', 'science', 'sport', 'study']
# ['vertebrate', 'comparative', 'anatomy', 'function', 'evolution']
# ['business', 'changing', 'world']
# ['law', 'business']
# ['essential', 'biology']
# ['power', 'choice', 'introduction', 'political', 'science']
# ['music', 'appreciation']
# ['music', 'appreciation']
# ['music', 'appreciation']
# ['accounting', 'mean']
# ['financial', 'statement', 'analysis', 'security', 'valuation']
# ['introduction', 'managerial', 'accounting']
# ['managerial', 'accounting', 'manager']
# ['fundamental', 'cost', 'accounting']
# ['financial', 'accounting']
# ['auditing', 'accounting', 'investigating', 'issue', 'fraud', 'professional', 'ethic']
# ['advanced', 'financial', 'accounting']
# ['financial', 'managerial', 'accounting']
# ['criminology']
# ['sociology', 'edition']
# ['sociology', 'brief', 'introduction']
# ['sociology', 'core']
# ['mapping', 'social', 'landscape', 'reading', 'sociology']
# ['sociology', 'module']
# ['practical', 'skeptic', 'core', 'concept', 'sociology']
# ['practical', 'skeptic', 'reading', 'sociology']
# ['social', 'construction', 'difference', 'inequality', 'race', 'class', 'gender', 'sexuality']
# ['sociology', 'matter']
# ['sociological', 'theory']
# ['applied', 'circuit', 'analysis']
# ['design', 'operational', 'amplifier', 'analog', 'integrated', 'circuit']
# ['analog', 'circuit', 'design', 'discrete', 'integrated']
# ['marketing', 'management', 'strategic', 'decision-making', 'approach']
# ['essential', 'marketing', 'research']
# ['marketing', 'management']
# ['marketing']
# ['advertising']
# ['marketing', 'core']
# ['marketing', 'strategy', 'decision-focused', 'approach']
# ['basic', 'marketing', 'marketing', 'strategy', 'planning', 'approach']
# ['marketing']
# ['business', 'management', 'entrepreneur', 'guidebook']
# ['international', 'business']
# ['global', 'marketing', 'contemporary', 'theory', 'practice']
# ['entrepreneurial', 'business']
# ['business', 'ethic', 'decision-making', 'personal', 'integrity', 'social', 'responsibility']
# ['business', 'society', 'stakeholder', 'ethic', 'public', 'policy', 'edition']
# ['fundamental', 'corporate', 'finance', 'standard', 'edition', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['fundamental', 'corporate', 'finance', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'esta']
# ['financial', 'market', 'institution', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate']
# ['analysis', 'financial', 'management', 'edition']
# ['essential', 'corporate', 'finance']
# ['principle', 'corporate', 'finance', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'estate', 'mcgraw-hill/irwin', 'series', 'finance', 'insureance', 'real', 'estate']
# ['corporate', 'finance', 'edition']
# ['focus', 'personal', 'finance', 'active', 'approach', 'help', 'you', 'develop', 'successful', 'financial', 'skill', 'mcgraw-hill/irwin', 'series', 'finance', 'insurance', 'real', 'esta']
# ['core', 'concept', 'cultural', 'anthropology']
# ['magic', 'witchcraft', 'religion', 'reader', 'anthropology', 'religion']
# ['human', 'specie', 'introduction', 'biological', 'anthropology']
# ['cultural', 'anthropology', 'appreciating', 'cultural', 'diversity']
# ['anthropology', 'appreciating', 'human', 'diversity']
# ['mirror', 'humanity', 'concise', 'introduction', 'cultural', 'anthropology']
# ['introducing', 'anthropology', 'integrated', 'approach']
# ['psychology', 'introduction']
# ['psychology', 'perspective', 'connection', 'edition']
# ['understanding', 'psychology']
# ['essential', 'understanding', 'psychology']
# ['social', 'psychology']
# ['psychological', 'testing', 'assessment', 'introduction', 'test', 'measurement']
# ['human', 'sexuality', 'diversity', 'contemporary', 'america', 'edition']
# ['experience', 'psychology']
# ['personality', 'psychology', 'domain', 'knowledge', 'human', 'nature']
# ['abnormal', 'psychology']
# ['understanding', 'human', 'sexuality']
# ['science', 'psychology', 'appreciative', 'view']
# ['looseleaf', 'sexuality']
# ['communicating', 'strategy', 'success', 'business', 'profession']
# ['basic', 'reading', 'moral', 'philosophy']
# ['element', 'moral', 'philosophy']
# ['experiencing', 'world', 'religion', 'loose', 'leaf', 'tradition', 'challenge', 'change']
# ['introduction', 'business', 'ethic']
# ['philosophy', 'power', 'idea']
# ['doe', 'center', 'hold', 'introduction', 'western', 'philosophy']
# ['moral', 'story', 'introduction', 'ethic']
# ['introduction', 'physical', 'education', 'fitness', 'sport']
# ['environmental', 'geology']
# ['laboratory', 'manual', 'physical', 'geology']
# ['biology', 'essential']
# ['managerial', 'accounting']
# ['experiencing', 'race', 'class', 'gender', 'united']
# ['meaning', 'difference', 'american', 'construction', 'race', 'sex', 'gender', 'social', 'class', 'sexual', 'orientation', 'disability']
# ['service', 'marketing', 'edition']
# ['global', 'business']
# ['business', 'government', 'society', 'managerial', 'perspective']
# ['culture', 'sketch', 'study', 'anthropology']
# ['scripture', 'world', 'religion']
# ['elementary', 'statistic', 'step', 'step', 'approach', 'formula', 'card']
# ['forensic', 'accounting']
# ['world', 'history', 'texas', 'edition']
# ['business', 'management', 'real-world', 'application', 'connection']
# ['bscs', 'biology', 'molecular', 'approach']
# ['aerodynamics', 'engineering', 'student', 'sixth', 'edition']
# ['real', 'analysis', 'workbook', 'solution']
# ['principle', 'real', 'analysis']
# ['probability', 'measure', 'theory']
# ['computer', 'organization', 'design', 'third', 'edition', 'companion', 'morgan', 'kaufmann', 'series', 'computer', 'architecture', 'design']
# ['introduction', 'probability', 'statistic', 'engineer', 'scientist', 'fourth', 'edition']
# ['computer', 'organization', 'design', 'hardware/software', 'interface']
# ['digital', 'evidence', 'computer', 'crime', 'third', 'edition', 'forensic', 'science', 'computer', 'internet']
# ['computer', 'organization', 'design']
# ['advanced', 'topic', 'forensic', 'dna', 'typing', 'third', 'edition']
# ['computer', 'organization', 'design', 'revised', 'fourth', 'edition', 'fourth', 'edition', 'hardware/software', 'interface', 'morgan', 'kaufmann', 'series', 'computer', 'architecture', 'design']
# ['data', 'mining', 'practical', 'machine', 'learning', 'tool', 'technique', 'third', 'edition', 'morgan', 'kaufmann', 'series', 'data', 'management', 'system']
# ['fundamental', 'forensic', 'science', 'edition']
# ['introduction', 'probability', 'model', 'tenth', 'edition']
# ['molecular', 'biology', 'understanding', 'genetic', 'revolution']
# ['differential', 'equation', 'dynamical', 'system', 'introduction', 'chaos', 'third', 'edition']
# ['introduction', 'security', 'ninth', 'edition']
# ['computer', 'network', 'system', 'approach']
# ['molecular', 'biology', 'technique', 'classroom', 'laboratory', 'manual']
# ['introduction', 'forestry', 'natural', 'resource']
# ['computer', 'machine', 'vision', 'theory', 'algorithm', 'practicality']
# ['probability', 'random', 'process', 'edition', 'application', 'signal', 'processing', 'communication']
# ['course', 'real', 'analysis', 'edition']
# ['computer', 'organization', 'design', 'fifth', 'edition', 'hardware/software', 'interface', 'morgan', 'kaufmann', 'series', 'computer', 'architecture', 'design']
# ['introduction', 'probability', 'model', 'eleventh', 'edition']
# ['introduction', 'homeland', 'security', 'principle', 'all-hazards', 'response']
# ['semi-riemannian', 'geometry', 'application', 'relativity']
# ['electronic', 'commerce', 'managerial', 'perspective']
# ['microprocessor', 'hardware', 'software', 'principle', 'application']
# ['soul', 'cinema', 'appreciation', 'film', 'music']
# ['computer', 'organization', 'architecture', 'designing', 'performance']
# ['microprocessor', 'programming', 'interfacing', 'software', 'hardware', 'application']
# ['introduction', 'real', 'analysis']
# ['differential', 'equation', 'linear', 'algebra']
# ['musical', 'theater', 'appreciation']
# ['microprocessor', 'microcomputer', 'hardware', 'software']
# ['literature', 'latin', 'america', 'antiquity']
# ['applied', 'partial', 'differential', 'equation', 'fourier', 'series', 'boundary', 'value']
# ['wildlife', 'ecology', 'management']
# ['forest', 'ecology', 'foundation', 'sustainable', 'forest', 'management', 'environmental', 'ethic', 'forestry']
# ['digital+microprocessor', 'fundamental']
# ['data', 'structure', 'c++', 'using', 'stl']
# ['digital', 'integrated', 'circuit', 'design', 'perspective']
# ['microprocessor', 'programming', 'interfacing', 'software', 'hardware', 'application']
# ['speech', 'language', 'processing', 'introduction', 'natural', 'language', 'processing', 'computational', 'linguistics', 'speech', 'recognition']
# ['structured', 'computer', 'organization']
# ['power', 'electronics', 'circuit', 'device', 'application', 'edition']
# ['programming', 'language', 'ansi', 'version']
# ['introduction', 'quantum', 'mechanic', 'edition']
# ['digital', 'electronics', 'laboratory', 'experiment', 'using', 'xilinx', 'cpld', 'xilinx', 'foundation', 'design', 'simulation', 'software', 'design', 'simulation', 'software']
# ['thermodynamics', 'heat', 'power']
# ['forensic', 'science', 'crime', 'scene', 'crime', 'lab']
# ['introduction', 'risk', 'management', 'insurance', 'edition', 'prentice', 'hall', 'series', 'finance']
# ['concept', 'programming', 'language', 'edition']
# ['parallel', 'programming', 'technique', 'application', 'using', 'networked', 'workstation', 'parallel', 'computer', 'edition']
# ['adts', 'data', 'structure', 'solving', 'c++']
# ['operating', 'system', 'design', 'implementation']
# ['differential', 'equation']
# ['real', 'analysis']
# ['essential', 'business', 'law', 'legal', 'e-commerce', 'ethical', 'global', 'environment']
# ['fundamental', 'probability', 'stochastic', 'process']
# ['probability', 'random', 'process']
# ['circuit', 'design', 'theory', 'application']
# ['partial', 'differential', 'equation', 'fourier', 'series', 'boundary', 'value']
# ['structured', 'computer', 'organization']
# ['principle', 'computer', 'organization', 'assembly', 'language']
# ['physic', 'scientist', 'engineer', 'modern', 'physic']
# ['introduction', 'computing', 'programming', 'java', 'multimedia', 'approach']
# ['solid', 'electronic', 'device']
# ['sacred', 'path', 'understanding', 'religion', 'world']
# ['motorola', 'microprocessor', 'family', 'assembly', 'language', 'interface', 'design', 'system', 'design']
# ['linguistic', 'perspective', 'language', 'education']
# ['principle', 'data', 'network', 'computer', 'communication']
# ['listening', 'music']
# ['cognition', 'psychology', 'mind', 'brain']
# ['history', 'eastern', 'art']
# ['testament', 'greek', 'beginner']
# ['differential', 'equation', 'linear', 'algebra']
# ['database', 'system']
# ['political', 'science', 'introduction', 'edition']
# ['calculus', 'graphical', 'numerical', 'algebraic', 'edition']
# ['marketing', 'management']
# ['cost', 'accounting']
# ['computer', 'network', 'edition']
# ['mechanical', 'vibration', 'edition']
# ['introduction', 'programming', 'using', 'visual', 'basic', 'edition', 'pearson', 'custom', 'computer', 'science']
# ['data', 'structure', 'object', 'using', 'c++']
# ['database', 'processing']
# ['electronic', 'commerce', 'managerial', 'social', 'network', 'perspective', 'edition']
# ['international', 'economics', 'theory', 'policy']
# ['strategic', 'management', 'business', 'policy', 'achieving', 'sustainability']
# ['crisis', 'intervention', 'criminal', 'justice', 'response', 'chaos', 'mayhem', 'disorder']
# ['java', 'introduction', 'solving', 'programming', 'edition', 'myprogramminglab']
# ['balanced', 'introduction', 'computer', 'science', 'edition']
# ['reinforced', 'concrete', 'mechanic', 'design', 'edition']
# ['marketing', 'real', 'people', 'real', 'choice']
# ['marketing', 'defined', 'explained', 'applied']
# ['technique', 'microbiology', 'student', 'handbook']
# ['aerodynamics', 'engineer']
# ['physic', 'scientist', 'engineer', 'modern', 'physic']
# ['physic', 'scientist', 'engineer', 'chap']
# ['operating', 'system', 'internals', 'design', 'principle']
# ['introduction', 'design', 'analysis', 'algorithm', 'edition']
# ['forensic', 'psychology']
# ['security', 'computing', 'edition']
# ['international', 'monetary', 'financial', 'economics', 'pearson', 'series', 'economics']
# ['framework', 'marketing', 'management']
# ['electronic', 'device', 'conventional', 'current', 'version', 'edition']
# ['accounting', 'information', 'system', 'edition']
# ['cost', 'accounting', 'student', 'value', 'edition', 'edition']
# ['advanced', 'accounting', 'edition']
# ['computer', 'science', 'overview']
# ['java', 'program', 'late', 'object']
# ['java', 'program']
# ['database', 'system', 'introduction', 'database', 'data', 'warehouse']
# ['data', 'structure', 'object', 'using', 'java']
# ['data', 'structure', 'algorithm', 'analysis', 'java']
# ['neuro-fuzzy', 'soft', 'computing', 'computational', 'approach', 'learning', 'machine', 'intelligence']
# ['educational', 'psychology', 'edition']
# ['convergence', 'race', 'ethnicity', 'gender', 'multiple', 'identity', 'counseling', 'edition', 'merrill', 'counseling']
# ['electronic', 'health', 'record', 'understanding', 'using', 'computerized', 'medical', 'record']
# ['electronic', 'device', 'circuit', 'theory', 'edition']
# ['modern', 'database', 'management', 'edition']
# ['hinduism']
# ['contemporary', 'business', 'online', 'commerce', 'law', 'legal', 'internet', 'ethical', 'global', 'environment']
# ['programming', 'world', 'wide', 'web', 'edition']
# ['computer', 'forensics', 'cyber', 'crime', 'introduction', 'edition']
# ['fundamental', 'chemical', 'engineering', 'thermodynamics', 'prentice', 'hall', 'international', 'series', 'physical', 'chemical', 'engineering', 'science']
# ['global', 'marketing', 'edition']
# ['e-commerce']
# ['economics', 'money', 'banking', 'financial', 'market', 'business', 'school', 'edition', 'edition', 'pearson', 'series', 'economics']
# ['database', 'concept', 'edition']
# ['business', 'data', 'network', 'security', 'edition']
# ['multinational', 'business', 'finance', 'edition', 'pearson', 'series', 'finance']
# ['bond', 'market', 'analysis', 'strategy', 'edition']
# ['marketing', 'introduction', 'edition']
# ['statistic', 'business', 'economics', 'edition']
# ['strategic', 'marketing', 'edition']
# ['introduction', 'management', 'science', 'edition']
# ['career', 'fitness', 'program', 'exercising', 'option', 'career', 'fitness', 'program', 'exercising', 'option', 'sukiennik', 'diane', 'author', 'paperback']
# ['economics', 'money', 'banking', 'financial', 'market', 'edition']
# ['economics', 'health', 'health', 'care', 'edition']
# ['computer', 'security']
# ['marketing', 'hospitality', 'tourism', 'edition']
# ['analyzing', 'computer', 'security', 'threat', 'vulnerability', 'countermeasure', 'approach']
# ['starting', 'programming', 'logic', 'design', 'edition']
# ['pharmacology', 'connection', 'nursing', 'practice', 'edition']
# ['speed', 'signaling', 'jitter', 'modeling', 'analysis', 'budgeting']
# ['absolute', 'java', 'edition']
# ['aerodynamics', 'engineer', 'edition']
# ['data', 'structure', 'algorithm', 'analysis', 'c++']
# ['ethic', 'information', 'age', 'edition']
# ['starting', 'java', 'control', 'structure', 'object', 'edition']
# ['computer', 'networking', 'top-down', 'approach', 'edition']
# ['legal', 'environment', 'business', 'online', 'commerce', 'edition']
# ['business', 'law', 'edition']
# ['hospital', 'operation', 'principle', 'efficiency', 'health', 'care', 'press', 'operation', 'management']
# ['engineering', 'mechanic', 'dynamic', 'edition']
# ['engineering', 'mechanic', 'static', 'edition']
# ['structured', 'computer', 'organization', 'edition']
# ['introduction', 'computing', 'programming', 'python', 'edition']
# ['computer', 'organization', 'architecture', 'edition', 'william', 'stalling', 'book', 'computer', 'data', 'communication']
# ['introduction', 'java', 'programming', 'comprehensive', 'version', 'edition']
# ['economics', 'micro', 'view', 'edition']
# ['international', 'economics', 'edition', 'pearson', 'economics']
# ['economics', 'principle', 'application', 'tool']
# ['e-marketing', 'edition']
# ['criminology', 'edition', 'justice', 'series']
# ['business', 'communication', 'edition']
# ['business', 'communication', 'essential']
# ['criminological', 'theory', 'edition']
# ['starting', 'java', 'control', 'structure', 'object', 'plus', 'myprogramminglab', 'pearson', 'etext', 'access', 'card', 'package', 'edition']
# ['program', 'edition']
# ['international', 'business', 'reality', 'edition']
# ['corporate', 'finance']
# ['principle', 'risk', 'management', 'insurance', 'edition', 'pearson', 'series', 'finance']
# ['fundamental', 'future', 'option', 'market', 'edition']
# ['foundation', 'finance', 'edition', 'pearson', 'series', 'finance']
# ['engineering', 'mechanic', 'static', 'plus', 'masteringengineering', 'pearson', 'etext', 'access', 'card', 'package', 'edition']
# ['economics']
# ['managerial', 'economics', 'edition']
# ['business', 'statistic', 'edition']
# ['principle', 'economics', 'edition']
# ['business', 'data', 'communications-', 'infrastructure', 'networking', 'security', 'edition']
# ['e-commerce', 'edition']
# ['pharmacology', 'nurse', 'pathophysiologic', 'approach']
# ['database', 'processing', 'fundamental', 'design', 'implementation', 'edition']
# ['statistic', 'manager', 'using', 'microsoft', 'excel']
# ['international', 'business', 'challenge', 'globalization', 'edition']
# ['marketing', 'research']
# ['principle', 'marketing', 'edition']
# ['corporate', 'finance', 'core']
# ['comprehensive', 'health', 'insurance', 'billing', 'coding', 'reimbursement', 'student', 'workbook']
# ['java', 'software', 'structure', 'designing', 'using', 'data', 'structure']
# ['mechanic', 'material', 'edition']
# ['fundamental', 'neural', 'network', 'architecture', 'algorithm', 'application']
# ['cryptography', 'network', 'security', 'principle', 'practice', 'edition']
# ['network', 'security', 'essential', 'application', 'standard', 'edition']
# ['java', 'foundation']
# ['criminology', 'integrative', 'introduction']
# ['e-commerce', 'essential']
# ['computer', 'network', 'internet', 'edition']
# ['prentice', 'hall', 'earth', 'science']
# ['computer', 'science', 'overview']
# ['essential', 'sociology', 'edition']
# ['operating', 'system', 'internals', 'design', 'principle', 'edition']
# ['history', 'dance', 'art', 'education']
# ['hinduism', 'cultural', 'perspective']
# ['wildlife', 'forest', 'forestry', 'principle', 'managing', 'forest', 'biological', 'diversity', 'edition']
# ['intel', 'microprocessor', 'edition']
# ['technical', 'communication', 'twenty-first', 'century']
# ['criminalistics', 'introduction', 'forensic', 'science', 'edition']
# ['electronics', 'fundamental', 'circuit', 'device', 'application']
# ['principle', 'electric', 'circuit', 'conventional', 'current', 'version']
# ['core', 'concept', 'pharmacology', 'edition', 'mynursingkit', 'series']
# ['contemporary', 'clinical', 'immunology', 'serology', 'pearson', 'clinical', 'laboratory', 'science']
# ['criminology', 'sociological', 'understanding']
# ['homeland', 'security']
# ['health', 'physical', 'assessment', 'nursing', 'edition']
# ['understanding', 'pharmacology', 'health', 'profession']
# ['doe', 'earth', 'physical', 'geology', 'process', 'science']
# ['differential', 'equation', 'computing', 'modeling']
# ['elementary', 'differential', 'equation', 'boundary', 'value']
# ['course', 'database', 'system']
# ['e-commerce', 'business', 'technology', 'society', 'edition']
# ['modern', 'operating', 'system']
# ['industrial', 'ecology', 'sustainable', 'engineering']
# ['contemporary', 'business', 'online', 'commerce', 'law']
# ['earth', 'science']
# ['christian', 'theological', 'tradition']
# ['course', 'probability']
# ['managing', 'business', 'process', 'flow']
# ['motorola', 'microprocessor', 'family', 'assembly', 'language', 'interface', 'design', 'system', 'design']
# ['differential', 'equation', 'linear', 'algebra']
# ['art', 'brief', 'history']
# ['solving', 'data', 'structure', 'using', 'java', 'multimedia', 'approach']
# ['computer', 'network', 'internet']
# ['history', 'modern', 'art']
# ['introductory', 'chemical', 'engineering', 'thermodynamics', 'edition', 'prentice', 'hall', 'international', 'series', 'physical', 'chemical', 'engineering', 'science']
# ['hcs', 'microprocessor']
# ['computer', 'organization', 'architecture', 'designing', 'performance']
# ['marketing', 'management', 'edition']
# ['computer', 'networking', 'top-down', 'approach']
# ['marketing', 'research', 'applied', 'orientation']
# ['contemporary', 'direct', 'interactive', 'marketing']
# ['fundamental', 'database', 'system', 'edition']
# ['electronic', 'commerce']
# ['data', 'structure', 'abstraction', 'java', 'edition']
# ['service', 'marketing', 'edition']
# ['introduction', 'electronic', 'commerce', 'edition', 'spectrum', 'book']
# ['electric', 'circuit', 'edition', 'masteringengineering', 'series']
# ['principle', 'risk', 'management', 'insurance', 'edition', 'prentice', 'hall', 'series', 'finance']
# ['history', 'art', 'africa']
# ['physic', 'scientist', 'engineer', 'modern', 'physic']
# ['network', 'flow', 'theory', 'algorithm', 'application']
# ['natural', 'language', 'processing', 'prolog', 'programmer']
# ['educational', 'psychology', 'theory', 'practice', 'edition', 'myeducationlab', 'series']
# ['mastering', 'method', 'differentiated', 'instruction', 'culturally', 'linguistically', 'diverse', 'cld', 'student', 'edition', 'myeducationkit', 'series']
# ['criminology', 'integrative', 'introduction', 'edition', 'mycrimekit', 'series']
# ['core', 'java', 'volume', 'fundamental', 'edition', 'sun', 'core', 'series']
# ['introductory', 'circuit', 'analysis', 'edition']
# ['linguistics', 'non-linguists', 'primer', 'exercise']
# ['esol', 'teacher', 'classroom', 'teacher', 'linguistically', 'culturally', 'ethnically', 'diverse', 'student']
# ['quantum', 'mechanic', 'engineering', 'material', 'science', 'applied', 'physic']
# ['e-commerce', 'edition']
# ['international', 'economics', 'theory', 'policy', 'student', 'value', 'edition', 'edition']
# ['introduction', 'islam', 'edition', 'mysearchlab', 'series', 'religion']
# ['life', 'health', 'insurance', 'edition']
# ['introduction', 'quantum', 'mechanic', 'chemistry']
# ['molecular', 'thermodynamics', 'fluid-phase', 'equilibrium']
# ['origin', 'virtue', 'human', 'instinct', 'evolution', 'cooperation']
# ['rise', 'fall', 'athens', 'nine', 'greek', 'life']
# ['evolution', 'true']
# ['dramaturgy', 'american', 'theater', 'source', 'book', 'source', 'book']
# ['basic', 'judaism']
# ['regional', 'farm', 'bill', 'field', 'hearing', 'redmond', 'oregon', 'hearing', 'committee', 'agriculture', 'nutrition', 'forestry', 'united', 'senate', 'hundred', 'ninth', 'congress', 'session', 'august']
# ['analytical', 'mechanic', 'relativity', 'quantum', 'mechanic', 'oxford', 'graduate', 'text']
# ['hinduism', 'short', 'introduction']
# ['judaism', 'short', 'introduction']
# ['foundation', 'buddhism']
# ['history', 'practice', 'ancient', 'astronomy']
# ['oxford', 'history', 'islam']
# ['testament', 'reader', 'christianity']
# ['classical', 'greek', 'reader']
# ['challenge', 'ethic', 'environmentalism', 'feminism', 'multiculturalism']
# ['introduction', 'game', 'theory']
# ['islamic', 'threat', 'myth', 'reality']
# ['anne', 'orthwood', 'bastard', 'sex', 'law', 'virginia']
# ['athenaze', 'introduction', 'ancient', 'greek']
# ['theorizing', 'feminism', 'reader']
# ['testament', 'christian', 'writing', 'reader']
# ['eight', 'theory', 'religion']
# ['islam', 'straight', 'path']
# ['playing', 'real', 'text', 'game', 'theory']
# ['oxford', 'encyclopedia', 'islamic', 'world', 'six-volume', 'set']
# ['buddhism']
# ['doe', 'feminism', 'discriminate', 'debate']
# ['introduction', 'game', 'theory', 'international', 'edition']
# ['microelectronic', 'circuit', 'oxford', 'series', 'electrical', 'computer', 'engineering']
# ['film', 'theory', 'criticism']
# ['magic', 'witchcraft', 'ghost', 'greek', 'roman', 'world', 'sourcebook']
# ['vold', 'theoretical', 'criminology']
# ['democracy', 'latin', 'america', 'political', 'change', 'comparative', 'perspective']
# ['anthropology', 'doe', 'mean', 'human']
# ['wave', 'oscillation', 'prelude', 'quantum', 'mechanic']
# ['islam', 'straight', 'path']
# ['conversation', 'historical', 'introduction', 'philosophy']
# ['oxford', 'handbook', 'judaism', 'economics']
# ['english', 'language', 'linguistic', 'history']
# ['concise', 'introduction', 'world', 'religion', 'edition']
# ['chinese', 'south-east', 'asian', 'white', 'ware', 'found', 'philippine']
# ['role', 'government', 'east', 'asian', 'economic', 'development', 'comparative', 'institutional', 'analysis']
# ['chaos', 'nonlinear', 'dynamic', 'introduction', 'scientist', 'engineer']
# ['chaos', 'time-series', 'analysis']
# ['proboscidea', 'evolution', 'palaeoecology', 'elephant', 'relative', 'oxford', 'science', 'publication']
# ['probability', 'random', 'process']
# ['introducing', 'einstein', 'relativity']
# ['dictionary', 'hinduism']
# ['latin', 'dictionary', 'founded', 'andrew', 'edition', 'freud', 'latin', 'dictionary']
# ['greek-english', 'lexicon']
# ['deuteronomy', 'judaean', 'diaspora']
# ['feminism', 'film']
# ['intermediate', 'greek-english', 'lexicon']
# ['biochemistry', 'molecular', 'biology']
# ['building', 'bioinformatics', 'solution', 'perl', 'mysql']
# ['relativity', 'einstein', 'equation']
# ['feminism', 'issue', 'argument']
# ['canon', 'criterion', 'christian', 'theology', 'father', 'feminism']
# ['evolution', 'introduction']
# ['woman', 'indian', 'buddhism', 'comparative', 'textual', 'study']
# ['cultural', 'anthropology', 'perspective', 'human', 'condition']
# ['molecular', 'quantum', 'mechanic']
# ['molecular', 'biology', 'principle', 'genome', 'function']
# ['relativity', 'gravitation', 'cosmology', 'basic', 'introduction', 'oxford', 'master', 'series', 'physic']
# ['molecular', 'biology', 'cancer', 'mechanism', 'target', 'therapeutic']
# ['einstein', 'physic', 'atom', 'quantum', 'relativity', 'derived', 'explained', 'appraised']
# ['introduction', 'medicinal', 'chemistry']
# ['biochemistry', 'molecular', 'basis', 'life']
# ['ecoimmunology']
# ['invitation', 'world', 'religion']
# ['gender', 'prism', 'difference']
# ['testament', 'historical', 'introduction', 'christian', 'writing']
# ['world', 'religion']
# ['introducing', 'philosophy', 'text', 'integrated', 'reading']
# ['crime', 'criminology']
# ['ethic', 'history', 'theory', 'contemporary', 'issue']
# ['exploring', 'philosophy', 'introductory', 'anthology']
# ['introduction', 'philosophy', 'classical', 'contemporary', 'reading']
# ['criminological', 'theory', 'introduction', 'evaluation', 'application']
# ['christ', 'messiah', 'christ', 'language', 'paul', 'messiah', 'language', 'ancient', 'judaism']
# ['talon', 'eagle', 'latin', 'america', 'united', 'world']
# ['marine', 'biology', 'function', 'biodiversity', 'ecology']
# ['american', 'popular', 'music']
# ['physical', 'geography', 'global', 'environment']
# ['buddhism', 'introducing', 'buddhist', 'experience']
# ['oxford', 'latin', 'course', 'college', 'edition', 'grammar', 'exercise', 'context']
# ['oxford', 'latin', 'course', 'college', 'edition', 'reading', 'vocabulary']
# ['colonial', 'latin', 'america']
# ['gendered', 'society']
# ['gendered', 'society', 'reader']
# ['josephus', 'theology', 'ancient', 'judaism']
# ['modern', 'latin', 'america']
# ['moral', 'life', 'introductory', 'reader', 'ethic', 'literature']
# ['reading', 'greek', 'history', 'source', 'interpretation']
# ['philosophy', 'quest', 'truth']
# ['advanced', 'quantum', 'mechanic']
# ['mechanic', 'thermodynamics', 'propulsion']
# ['genetic', 'algorithm', 'search', 'optimization', 'machine', 'learning']
# ['exploring', 'black', 'hole', 'introduction', 'relativity']
# ['real', 'analysis', 'course', 'edition']
# ['modern', 'quantum', 'mechanic']
# ['nonlinear', 'dynamics+chaos']
# ['concrete', 'mathematics', 'foundation', 'computer', 'science']
# ['computer', 'system', 'organization', 'architecture']
# ['design', 'implementation', 'freebsd', 'operating', 'system']
# ['course', 'probability']
# ['art', 'computer', 'programming', 'volume', 'fundamental', 'algorithm', 'edition']
# ['literature', 'introduction', 'reading', 'writing', 'edition']
# ['agenda', 'alternative', 'public', 'policy', 'update', 'edition', 'epilogue', 'health', 'care', 'edition', 'longman', 'classic', 'political', 'science']
# ['greek', 'art', 'archaeology', 'edition']
# ['gender', 'psychological', 'perspective', 'edition']
# ['human', 'sexuality', 'edition', 'mydevelopmentlab', 'series']
# ['art', 'brief', 'history']
# ['business', 'ethic', 'concept']
# ['jew', 'christian', 'muslim', 'comparative', 'introduction', 'monotheistic', 'religion']
# ['medium', 'ethic', 'moral', 'reasoning', 'edition']
# ['english', 'linguistic', 'introduction']
# ['introduction', 'bible', 'edition']
# ['concise', 'introduction', 'linguistics']
# ['latin', 'america', 'people', 'combined', 'volume', 'edition']
# ['short', 'guide', 'writing', 'biology', 'edition']
# ['vision', 'america', 'history', 'united', 'volume', 'edition']
# ['sociology', 'project', 'introducing', 'sociological', 'imagination']
# ['sociology', 'down-to-earth', 'approach', 'edition']
# ['sociology', 'edition']
# ['biological', 'anthropology']
# ['backpack', 'literature', 'introduction', 'fiction', 'poetry', 'drama', 'writing', 'edition']
# ['religion', 'world']
# ['history', 'world', 'religion']
# ['psychology']
# ['social', 'psychology', 'united', 'edition']
# ['core', 'question', 'philosophy', 'text', 'reading', 'edition', 'mythinkinglab', 'series']
# ['forensic', 'psychology']
# ['human', 'sexuality']
# ['human', 'sexuality', 'paper', 'edition']
# ['living', 'religion', 'brief', 'introduction']
# ['literature', 'introduction', 'fiction', 'poetry', 'drama', 'writing', 'edition']
# ['human', 'evolution', 'culture', 'highlight', 'anthropology', 'edition']
# ['conformity', 'conflict', 'reading', 'cultural', 'anthropology', 'edition', 'myanthrolab', 'series']
# ['short', 'guide', 'writing', 'film']
# ['art', 'brief', 'history', 'plus', 'myartslab', 'access', 'card', 'package', 'edition']
# ['physiology', 'behavior', 'edition']
# ['janson', 'basic', 'history', 'western', 'art', 'edition', 'history', 'art']
# ['statistic', 'psychology']
# ['history', 'modern', 'art', 'paperback', 'edition']
# ['history', 'modern', 'art', 'volume']
# ['human', 'biology', 'social', 'worker', 'development', 'ecology', 'genetics', 'health']
# ['anthropology', 'latin', 'america', 'caribbean']
# ['understanding', 'music', 'edition']
# ['head', 'broadcasting', 'america', 'survey', 'electronic', 'medium']
# ['writing', 'political', 'science', 'practical', 'guide']
# ['history', 'film']
# ['religion', 'matter', 'sociology', 'teach', 'religion', 'world']
# ['introduction', 'literature', 'edition']
# ['visual', 'art', 'history', 'revised', 'edition']
# ['janson', 'history', 'art', 'western', 'tradition', 'edition']
# ['janson', 'history', 'art', 'western', 'tradition', 'volume', 'edition', 'myartslab', 'series']
# ['janson', 'history', 'art', 'western', 'tradition', 'volume', 'edition']
# ['flashback', 'brief', 'film', 'history']
# ['greek', 'history', 'culture', 'society']
# ['history', 'italian', 'renaissance', 'art', 'paper', 'cover', 'edition', 'mysearchlab', 'series', 'art']
# ['photography', 'cultural', 'history', 'edition', 'mysearchlab', 'series', 'art', 'mysearchlab', 'series', 'art']
# ['latin', 'america', 'interpretive', 'history']
# ['world', 'history', 'edition']
# ['consider', 'source', 'document', 'latin', 'american', 'history', 'interpretive', 'history']
# ['sociology', 'religion', 'reader']
# ...
# ['illustrated', 'dental', 'embryology', 'histology', 'anatomy']
# ['krause', 'food', 'nutrition', 'care', 'process', 'krause', 'food', 'nutrition', 'therapy']
# ['pharmacology', 'principle', 'application']
# ['study', 'guide', 'pharmacology', 'nursing', 'care']
# ['pharmacology', 'nursing', 'care']
# ['twenty', 'question', 'introduction', 'philosophy']
# ['cost', 'accounting', 'foundation', 'evolution']
# ['nutrition', 'therapy', 'pathophysiology']
# ['foundation', 'astronomy']
# ['understanding', 'operating', 'system']
# ['connecting', 'computer', 'science']
# ['probability', 'statistic', 'reliability', 'engineer', 'scientist']
# ['computer', 'network', 'time', 'synchronization', 'network', 'time', 'protocol', 'earth', 'space']
# ['pension', 'fund', 'risk', 'management', 'financial', 'actuarial', 'modeling', 'chapman', 'hall/crc', 'finance', 'series']
# ['handbook', 'solvency', 'actuary', 'risk', 'manager']
# ['course', 'machine', 'learning']
# ['forensic', 'science', 'introduction', 'scientific', 'investigative', 'technique', 'fourth', 'edition']
# ['machine', 'learning', 'business', 'analytics']
# ['meditation', 'judaism', 'christianity', 'islam', 'cultural', 'history']
# ['dynamic', 'east', 'asian', 'politics', 'security', 'political', 'economy', 'society']
# ['statistical', 'method', 'bioinformatics', 'introduction']
# ['advanced', 'quantum', 'mechanic', 'material', 'photon', 'graduate', 'text', 'physic']
# ['principle', 'distributed', 'database', 'system']
# ['philosophy', 'sex']
# ['feminism', 'matter', 'debate', 'theory', 'activism']
# ['discovering', 'statistic', 'using', 'ibm', 'spss', 'statistic']
# ['guide', 'computer', 'network', 'security', 'computer', 'communication', 'network']
# ['essential', 'computer', 'organization', 'architecture']
# ['molecular', 'biology', 'gene', 'protein']
# ['object-oriented', 'data', 'structure', 'using', 'java']
# ['essential', 'computer', 'organization', 'architecture']
# ['principle', 'modern', 'operating', 'system']
# ['java', 'illuminated', 'active', 'learning', 'approach']
# ['c++', 'plus', 'data', 'structure']
# ['elementary', 'information', 'security']
# ['essential', 'health', 'policy', 'law', 'essential', 'public', 'health']
# ['discovering', 'nutrition']
# ['introduction', 'human', 'disease', 'pathology', 'pathophysiology', 'correlation']
# ['computer', 'science', 'illuminated']
# ['christian', 'path', 'health', 'edition']
# ['immunology', 'lippincott', 'illustrated', 'review', 'series']
# ['lippincott', 'illustrated', 'review', 'pharmacology', 'lippincott', 'illustrated', 'review', 'series']
# ['washington', 'manual', 'allergy', 'asthma', 'immunology', 'subspecialty', 'consult', 'washington', 'manual', 'subspecialty', 'consult', 'series']
# ['essential', 'pathophysiology', 'text', 'study', 'guide', 'package']
# ['focus', 'nursing', 'pharmacology']
# ['porth', 'pathophysiology', 'concept', 'altered', 'health']
# ['primary', 'care', 'medicine']
# ['microbiology', 'immunology', 'board', 'review', 'series']
# ['practical', 'essential', 'intensity', 'modulated', 'radiation', 'therapy']
# ['acsm', 'introduction', 'exercise', 'science']
# ['pocket', 'medicine', 'massachusetts', 'hospital', 'handbook', 'internal', 'medicine']
# ['washington', 'manual', 'medical', 'therapeutic', 'print', 'online']
# ['pocket', 'medicine', 'massachusetts', 'hospital', 'handbook', 'internal', 'medicine', 'pocket', 'notebook']
# ['relativity', 'deviance']
# ['race', 'ethnicity', 'gender', 'class', 'sociology', 'conflict', 'change']
# ['racism', 'sexism', 'medium', 'multicultural', 'issue', 'communication', 'age']
# ['novel', 'approach', 'politics', 'introducing', 'political', 'science', 'book', 'movie', 'popular', 'culture', 'edition']
# ['preparing', 'educator', 'engage', 'family', 'study', 'using', 'ecological', 'system', 'framework']
# ['introduction', 'criminology', 'theory', 'method', 'criminal', 'behavior']
# ['practice', 'research', 'criminology', 'criminal', 'justice']
# ['introduction', 'criminology', 'text/reader']
# ['sociology', 'exploring', 'architecture', 'everyday', 'life']
# ['statistic', 'people', 'hate', 'statistic']
# ['ethical', 'practice', 'law', 'edition']
# ['secured', 'credit', 'system', 'approach', 'seventh', 'edition', 'aspen', 'casebook']
# ['constitutional', 'law']
# ['criminal', 'law', 'process', 'material', 'aspen', 'casebook', 'series', 'edition']
# ['constitutional', 'law', 'seventh', 'edition', 'aspen', 'casebook', 'series']
# ['rule', 'contract', 'law', 'statutory', 'supplement']
# ['veterinary', 'immunology', 'introduction']
# ['atlas', 'human', 'anatomy', 'including', 'student', 'consult', 'interactive', 'ancillaries', 'guide']
# ['basic', 'immunology', 'function', 'disorder', 'immune', 'system']
# ['health', 'insurance', 'text', 'workbook', 'package', 'practical', 'approach']
# ['pathophysiology']
# ['language', 'medicine']
# ['insurance', 'handbook', 'medical', 'office']
# ['pharmacology', 'patient-centered', 'nursing', 'process', 'approach', 'kee', 'pharmacology']
# ['gould', 'pathophysiology', 'health', 'profession']
# ['medical', 'terminology', 'online', 'language', 'medicine', 'access', 'code', 'textbook', 'package']
# ['study', 'guide', 'pharmacology', 'patient-centered', 'nursing', 'process', 'approach']
# ['literature', 'human', 'experience', 'reading', 'writing']
# ['literature', 'portable', 'anthology']
# ['bedford', 'introduction', 'literature', 'reading', 'thinking', 'writing']
# ['bioinformatics', 'throughput', 'sequencing']
# ['perspective', 'industrial', 'organization', 'contribution', 'behavioral', 'economics', 'game', 'theory', 'springer', 'text', 'business', 'economics']
# ['discovering', 'psychology']
# ['basic', 'practice', 'statistic', 'w/student']
# ['psychology', 'module']
# ['life', 'guide', 'biology', 'prep-u']
# ['life', 'guide', 'biology', 'physiology', 'prep-u']
# ['world', 'regional', 'geography', 'subregions']
# ['world', 'regional', 'geography']
# ['exploring', 'psychology', 'paper']
# ['exploring', 'psychology', 'module', 'loose-leaf', 'book', 'ninth', 'edition', 'david', 'myers']
# ['abnormal', 'psychology', 'update']
# ['investigating', 'astronomy']
# ['introduction', 'practice', 'statistic', 'w/crunchit/eesee', 'access', 'card']
# ['exploring', 'psychology', 'update']
# ['embedded', 'system', 'real-time', 'operating', 'system', 'arm', 'cortex', 'microcontrollers']
# ['linear', 'algebra', 'probability', 'computer', 'science', 'application']
# ['homeland', 'security', 'introduction', 'principle', 'practice', 'edition']
# ['introduction', 'computer', 'network', 'cybersecurity']
# ['network', 'anomaly', 'detection', 'machine', 'learning', 'perspective']
# ['fundamental', 'research', 'criminology', 'criminal', 'justice']
# ['essential', 'sociology']
# ['forestry', 'a-z']
# ['theater', 'tip', 'strategy', 'jury', 'trial']
# ['classical', 'tragedy', 'greek', 'roman', 'play', 'authoritative', 'modern', 'translation', 'accompanied', 'critical', 'essay']
# ['guide', 'code', 'ethic', 'nurse']
# ['program', 'machine', 'learning']
# ['computer', 'organization', 'design', 'hardware/software', 'interface', 'student', 'edition']
# ['taking', 'boy', 'feminism', 'family', 'business', 'nation']
# ['african', 'diaspora', 'mediterranean', 'land', 'islam']
# ['positive', 'impact', 'forestry', 'sustainability', 'approach', 'managing', 'woodland']
# ['time', 'bed', 'secret', 'shadow']
# ['skin', 'talking', 'sex', 'class', 'literature']
# ['intake', 'aerodynamics', 'aiaa', 'education', 'series']
# ['linguistics', 'american', 'sign', 'language', 'introduction']
# ['maya', 'diaspora', 'guatemalan', 'root', 'american', 'life']
# ['united', 'history', 'preparing', 'advanced', 'placement', 'examination']
# ['sacred', 'east', 'illustrated', 'guide', 'buddhism', 'hinduism', 'confucianism', 'taoism', 'shinto']
# ['compressor', 'aerodynamics']
# ['islam', 'muslim', 'community']
# ['buddhism', 'path', 'nirvana', 'religious', 'tradition', 'world']
# ['urban', 'forestry', 'planning', 'managing', 'urban', 'greenspaces']
# ['classic', 'criminology', 'edition']
# ['colonize', 'this', 'young', 'woman', 'color', 'feminism']
# ['frontal', 'feminism', 'young', 'woman', 'guide', 'feminism', 'matter']
# ['history', 'u.s.', 'feminism']
# ['feminism', 'pop', 'culture', 'seal', 'study']
# ['essential', 'pathophysiology', 'concept', 'altered', 'health']
# ['walking', 'god', 'classroom', 'christian', 'approach', 'teaching', 'learning']
# ['clinical', 'management', 'sex', 'addiction']
# ['microprocessor', 'assembly', 'language', 'using']
# ['modern', 'actuarial', 'theory', 'practice']
# ['statistical', 'probabilistic', 'method', 'actuarial', 'science']
# ['applied', 'game', 'theory', 'strategic', 'behavior']
# ['introduction', 'latin']
# ['aerodynamic', 'design', 'transport', 'aircraft']
# ['asian', 'hemisphere', 'irresistible', 'shift', 'global', 'power', 'east']
# ['enemy', 'question', 'american', 'christian', 'islam', 'themselves']
# ['radin', 'rothchild', 'reese', 'silverman', 'internet', 'commerce', 'emerging', 'legal', 'framework', 'university', 'casebook', 'series', 'english', 'english', 'edition']
# ['study', 'guide', 'solution', 'manual', 'exam', 'society', 'actuary', 'edition']
# ['alif', 'baa', 'third', 'edition', 'alif', 'baa', 'introduction', 'arabic', 'letter', 'sound', 'al-kitaab', 'arabic', 'language', 'program', 'arabic', 'edition']
# ['python', 'programming', 'introduction', 'computer', 'science']
# ['art', 'buddhism', 'introduction', 'history', 'meaning']
# ['introduction', 'thermodynamics', 'material']
# ['inside', 'machine', 'illustrated', 'introduction', 'microprocessor', 'computer', 'architecture']
# ['principle', 'practice', 'sex', 'therapy']
# ['feminism', 'seduced', 'global', 'elite', 'woman', 'labor', 'idea', 'exploit', 'world']
# ['security', 'regulation', 'analysis', 'university', 'casebook', 'series']
# ['christian', 'morality', 'student', 'book', 'response', 'god', 'love']
# ['judaism', 'gentile']
# ['reading', 'ancient', 'greek', 'philosophy', 'thales', 'aristotle']
# ['atlas', 'anatomy']
# ['mahamudra', 'modern', 'world', 'unprecedented', 'training', 'course', 'pinnacle', 'teaching', 'tibetan', 'buddhism']
# ['latin', 'american', 'identity', 'african', 'diaspora', 'ethnogenesis', 'context']
# ['evolution', 'third', 'edition']
# ['acc', 'atlas', 'pathophysiology']
# ['pathophysiology', 'clinical', 'approach']
# ['clinical', 'anesthesia', 'procedure', 'massachusetts', 'hospital', 'department', 'anesthesia', 'critical', 'care', 'pain', 'medicine', 'massachusetts', 'hospital', 'harvard', 'medical', 'school']
# ['burton', 'microbiology', 'health', 'science', 'north', 'american', 'edition']
# ['radiation', 'oncology', 'management', 'decision']
# ['handbook', 'research', 'machine', 'learning', 'application', 'trend', 'algorithm', 'method', 'technique', 'volume']
# ['principle', 'pharmacology']
# ['mark', 'basic', 'medical', 'biochemistry', 'lieberman', 'mark', 'basic', 'medical', 'biochemistry']
# ['pharmacology', 'health', 'professional']
# ['pocket', 'medicine', 'massachusetts', 'hospital', 'handbook', 'internal', 'medicine', 'pocket', 'notebook', 'series']
# ['political', 'science', 'research', 'method']
# ['encyclopedia', 'hinduism']
# ['diaspora', 'christianity', 'religion', 'secularity']
# ['medical', 'physiology', 'principle', 'clinical', 'medicine', 'north', 'american', 'edition', 'medical', 'physiology', 'rhoades']
# ['exploring', 'anatomy', 'physiology', 'laboratory']
# ['algorithm', 'design', 'manual']
# ['compressible', 'aerodynamics']
# ['introducing', 'hinduism', 'graphic', 'guide', 'introducing', '...']
# ['essay', 'game', 'theory']
# ['connectionist', 'natural', 'language', 'processing', 'reading', 'connection', 'science']
# ['hinduism', 'frequently', 'question']
# ['guide', 'getting', 'book', 'wonder', 'sex']
# ['introduction', 'probability', 'edition']
# ['molecular', 'thermodynamics']
# ['special', 'relativity']
# ['modern', 'approach', 'quantum', 'mechanic']
# ['developmentally', 'appropriate', 'practice', 'childhood', 'program', 'serving', 'child', 'birth', 'age']
# ['african', 'america', 'history', 'black', 'diaspora']
# ['diction', 'singer']
# ['cross-border', 'commerce']
# ['evolution', 'sense', 'life']
# ['evolution', 'sense', 'life']
# ['tool', 'technique', 'life', 'insurance', 'planning', 'edition']
# ['green', 'process', 'green', 'synthesis']
# ['natural', 'language', 'processing', 'information', 'system', 'international', 'conference', 'applicatioins', 'natural', 'language', 'information', 'system', 'nldb', 'alicante', 'spain', 'june', 'proceeding']
# ['natural', 'language', 'processing-ijcnlp', 'international', 'joint', 'conference', 'jeju', 'island', 'korea', 'october', 'proceeding']
# ['critical', 'phenomenon', 'natural', 'science', 'chaos', 'fractal', 'selforganization', 'disorder', 'concept', 'tool']
# ['natural', 'language', 'processing', 'information', 'system', 'international', 'conference', 'application', 'natural', 'language', 'information', 'system', 'nldb', 'klagenfurt', 'austria', 'proceed']
# ['advance', 'natural', 'language', 'processing', 'international', 'conference', 'nlp', 'fintal', 'turku', 'finland', 'august', 'proceeding']
# ['aerodynamic', 'drag', 'reduction', 'technology', 'proceeding', 'ceas/dragnet', 'european', 'drag', 'reduction', 'conference', 'june', 'potsdam', 'germany', 'note', '...', 'fluid', 'mechanic', 'multidisciplinary', 'design']
# ['advance', 'natural', 'language', 'processing', 'third', 'international', 'conference', 'portal', 'faro', 'portugal', 'june', 'proceeding']
# ['natural', 'language', 'processing']
# ['evaluating', 'natural', 'language', 'processing', 'system', 'analysis', 'review']
# ['natural', 'language', 'processing', 'nlp', 'international', 'conference', 'patras', 'greece', 'june', 'proceeding']
# ['computer', 'network', 'security', 'theory', 'practice']
# ['modern', 'actuarial', 'risk', 'theory', 'using']
# ['aerodynamic', 'drag', 'reduction', 'technology', 'proceeding', 'ceas/dragnet', 'european', 'drag', 'reduction', 'conference', 'june', 'potsdam', 'germany', 'note', '...', 'mechanic', 'multidisciplinary', 'design']
# ['optimization', 'chaos', 'study', 'economic', 'theory']
# ['chaos', 'structural', 'mechanic', 'understanding', 'complex', 'system']
# ['landscape', 'ecology', 'forest', 'management', 'conservation', 'challenge', 'solution', 'global', 'change']
# ['total', 'artwork', 'expressionism', 'art', 'film', 'literature', 'theater', 'dance', 'architecture']
# ['theater', 'manner', 'photograph', 'tina', 'barney', 'tina', 'barney']
# ['mathematical', 'foundation', 'computer', 'science']
# ['introduction', 'hinduism']
# ['tribute', 'hinduism', 'wisdom', 'spanning', 'continent', 'time', 'india']
# ['relativity', 'field', 'theory', 'introduction', 'special', 'relativity', 'classical', 'quantum', 'field', 'theory']
# ['mediating', 'divine', 'prophecy', 'revelation', 'dead', 'sea', 'scroll', 'temple', 'judaism']
# ['wandering', 'galilean', 'essay', 'honour', 'sean', 'freyne', 'supplement', 'journal', 'study', 'judaism']
# ['constructing', 'irregular', 'theology', 'bamboo', 'minjung', 'east', 'asian', 'perspective', 'study', 'systematic', 'theology']
# ['testament', 'rabbinic', 'literature', 'supplement', 'journal', 'study', 'judaism']
# ['esoteric', 'buddhism', 'tantra', 'east', 'asia', 'handbook', 'oriental', 'study']
# ['aerodynamics', 'bridge', 'proceeding', 'international', 'symposium', 'copenhagen', 'denmark', 'february']
# ['judaism', 'origin', 'christianity']
# ['south-east', 'asian', 'ceramic', 'thai', 'vietnamese', 'khmer', 'collection', 'art', 'gallery', 'south', 'australia', 'adelaide', 'asia', 'collection']
# ['solution', 'quantum', 'mechanic', 'major', 'american', 'university', 'qualifying', 'question', 'solution']
# ['introduction', 'compiler', 'construction', 'java', 'world']
# ['data', 'structure', 'algorithm', 'java']
# ['game', 'theory', 'nontechnical', 'introduction', 'analysis', 'strategy']
# ['society', 'actuary', 'textbook', 'life', 'contingency', 'chester', 'wallace', 'jordan', 'paperback']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-f99bbe0109ee> in <module>()
#      64 Z = svd.fit_transform(X)
#      65
# ---> 66 plt.scatter(Z[:,0],Z[:,1])
#      67 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'
